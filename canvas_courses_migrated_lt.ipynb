# %%
import pandas as pd
import numpy as np
import requests

from pandas.io import gbq
from google.cloud import bigquery,storage
from google.oauth2 import service_account

import gspread

from canvasapi import Canvas

import plotly.express as px

from instances import env_keys
#API_KEY = env_keys['API_key']
API_KEY = env_keys['ACCES_TOKEN']
API_URL = env_keys['API_URL']#+'/accounts/1'

# %%
project_id = 'canvas-portal-data-custom'
cred_file = 'canvas-portal-data-custom-6e244db3b826.json'
data_dl = 'data'
scopes = [ "https://www.googleapis.com/auth/drive", "https://www.googleapis.com/auth/drive.file",
            "https://spreadsheets.google.com/auth/spreadsheets"]
credentials = service_account.Credentials.from_service_account_file(cred_file,)

# %%
# Initialize a new Canvas object
canvas = Canvas(API_URL, API_KEY)
canvas.__dict__
# Out:
# {'_Canvas__requester': <canvasapi.requester.Requester at 0x10732ac18>}

# %% [markdown]
# ### Get courses running on Canvas -- created via migration or by LT's

# %%
#Get the LT list from the Excel sheet
lt_df_cols = ['School', 'Dept_num', 'Dept_name', 'Name', 'Email']
lt_df = pd.read_excel('Learning_Technologists_updating.xlsx')
lt_df.columns = lt_df_cols
lt_df['Email'] = lt_df.Email.str.lower()
lt_df.tail()
# Out:
#    School Dept_num                   Dept_name                       Name  \
# 39      ?      ESG                         ESG  Mariela M Perez-Cabarcas
# 40      ?      HST                         HST              Keegan Mendez
# 41      A      MAS                   Media Lab              Kaili Glasser
# 42      ?       OL              Open Leearning              Lorcan Murphy
# 43      H      WGS  Women's and Gender Studies              Anna Williams
#
#                Email
# 39  mmpc2000@mit.edu
# 40   kmendez@mit.edu
# 41  glasserk@mit.edu
# 42   murphyl@mit.edu
# 43   ajlwill@mit.edu

# %%
#Read the Stellar to Canvas migration list on Google Drive, and construct a
#list of course_id s
gs_name = "Stellar to Canvas content migration request (Responses)"
#gs_name = "xyz"
gc = gspread.service_account(filename=cred_file)
sh = gc.open(gs_name).sheet1
sh_data = sh.get_all_values()
head_col = sh_data.pop(0)
stellar_df = pd.DataFrame(sh_data, columns=head_col)
stellar_df['course_id'] = stellar_df['Canvas URL to migrate to'].str.split("/").str[-1]

# %%
def get_course_info(course_id):
    '''This function gets the course information and the file/assignment update times,
    by the course_id, and returns a list of '''
    try:
        c1 = canvas.get_course(course_id)


        course_dept = sub_account_dict[c1.account_id]
        course_name = c1.name

        files_ = c1.get_files()
        assn_ = c1.get_assignments()
        #Get the file updated times
        file_utimes = [f_.updated_at for f_ in files_]

        #Get the assignment updated times
        assn_utimes = [a_.updated_at for a_ in assn_]
        fa_times = file_utimes + assn_utimes

        #Convert the whole thing 
        fa_times = np.array(fa_times, dtype='datetime64')



        return [c1.id, course_dept, course_name, len(file_utimes), len(assn_utimes), 
                len(fa_times), fa_times.max()]
    except Exception as e:
        return [None, None, None, None, None, None, None]

# %%
#Get a list of all department names by the sub-account id:
acc = canvas.get_account(1)
sub_account_dict = {}
accs = acc.get_subaccounts(recursive=True)
for a_ in accs:
    sub_account_dict[a_.id] = a_.name

#sub_account_dict

# %%
#Change line #7 for full list
stellar_df_course_list = stellar_df.course_id.tolist()
migrated_course_rows = []
migrated_course_cols = ['course_id','Dept', 'Course_name', 'num_files', 'num_assignments', 'num_tot_fa',
                        'last_update_at']

for c_id in stellar_df_course_list[:5]:
    migrated_course_rows.append(get_course_info(c_id))
    
migrated_course_df = pd.DataFrame.from_records(migrated_course_rows, columns=migrated_course_cols)
migrated_course_df['if_LT_led'] = 0
migrated_course_df['LT_email'] = np.nan
#migrated_course_df.tail()
# Out:
# /Users/anindyaroy/Sites/fun/venv/lib/python3.6/site-packages/ipykernel_launcher.py:21: DeprecationWarning:
#
# parsing timezone aware datetimes is deprecated; this will raise an error in the future
#    course_id                                        Dept  \
# 0       4631                   7 - Department of Biology
# 1       4579                   7 - Department of Biology
# 2       4691  CMS - Program in Comparative Media Studies
# 3       4774               ES - Experimental Study Group
# 4       3782              18 - Department of Mathematics
#
#                               Course_name  num_files  num_assignments  \
# 0              7.012 Introductory Biology         59               34
# 1  7.493 Microbial Genetics and Evolution        106               23
# 2     CMS.594 Education Technology Studio         40               34
# 3            ES.7012 Introductory Biology        130               19
# 4                        18.701 Algebra I         22                5
#
#    num_tot_fa      last_update_at  if_LT_led  LT_email
# 0          93 2020-06-30 22:32:48          0       NaN
# 1         129 2020-07-07 21:53:20          0       NaN
# 2          74 2020-06-30 04:53:54          0       NaN
# 3         149 2020-07-02 22:14:25          0       NaN
# 4          27 2020-06-16 23:36:29          0       NaN

# %%
#Change line #5 for full list
lt_courses_row = []
lt_courses_cols = migrated_course_cols + ['if_LT_led','LT_email']
courses_to_exclude = [3157, 3158]
for user_email in lt_df.Email.tolist()[:5]:
    try:
        user_ = canvas.get_user(user_email, 'sis_login_id')
        course_list = []
        user_courses = user_.get_enrollments(type=['TeacherEnrollment'])

        for uc_ in user_courses:
            #print(uc_.id, uc_.course_id)
            if uc_.course_id not in courses_to_exclude:
                uc_row = get_course_info(uc_.course_id)
                #print(uc_row)
                uc_row.extend([1, user_email])
                lt_courses_row.append(uc_row)
    except Exception as e:
        print('Error {} for user {}'.format(e, user_email))
        pass

        
all_lt_courses = pd.DataFrame.from_records(lt_courses_row, columns=lt_courses_cols)
#all_lt_courses
# Out:
# /Users/anindyaroy/Sites/fun/venv/lib/python3.6/site-packages/ipykernel_launcher.py:21: DeprecationWarning:
#
# parsing timezone aware datetimes is deprecated; this will raise an error in the future
#     course_id                                               Dept  \
# 0        5051                                          Sandboxes
# 1        3170  1 - Department of Civil and Environmental Engi...
# 2        3165  1 - Department of Civil and Environmental Engi...
# 3        3305  1 - Department of Civil and Environmental Engi...
# 4        5397  1 - Department of Civil and Environmental Engi...
# 5        3214  1 - Department of Civil and Environmental Engi...
# 6        3317  1 - Department of Civil and Environmental Engi...
# 7        5005                                          Sandboxes
# 8        5068                                          Sandboxes
# 9        3708           2 - Department of Mechanical Engineering
# 10       5049                                          Sandboxes
# 11       4110  3 - Department of Materials Science and Engine...
# 12       5049                                          Sandboxes
# 13       5313  3 - Department of Materials Science and Engine...
# 14       4127  3 - Department of Materials Science and Engine...
# 15       4113  3 - Department of Materials Science and Engine...
# 16       4226  3 - Department of Materials Science and Engine...
# 17       4164  3 - Department of Materials Science and Engine...
# 18       4183  3 - Department of Materials Science and Engine...
# 19       5073                                          Sandboxes
#
#                             Course_name  num_files  num_assignments  \
# 0                     Temporary Sandbox         30                9
# 1     1.008 Eng Solutions to Soc Change         84                4
# 2       1.000 Intro to Comp Programming         22                4
# 3           1.723 Computational Methods         22                4
# 4   1.74 Land, Water, Food, and Climate         99                5
# 5    1.061 Transport Processes in Envir         22                5
# 6           1.976 Grad Prof Dev Seminar         22                4
# 7                     Temporary Sandbox         23                4
# 8                           Demo Course         28                4
# 9       2.001 Mechanics and Materials I         38               30
# 10                    Temporary Sandbox         98               37
# 11    3.034 Organic & Biomaterials Chem         70               45
# 12                    Temporary Sandbox         98               37
# 13     3.032 Mech Behavior of Materials         98               38
# 14        3.07 Introduction to Ceramics         57               24
# 15   3.042 Materials Project Laboratory         22               14
# 16  3.986 Human Past: Intro Archaeology         63               59
# 17          3.24 Structure of Materials         72               29
# 18     3.42 Electronic Materials Design         49               42
# 19                    Temporary Sandbox         24                4
#
#     num_tot_fa      last_update_at  if_LT_led          LT_email
# 0           39 2020-07-03 14:51:22          1  zroberts@mit.edu
# 1           88 2020-06-12 17:34:00          1  zroberts@mit.edu
# 2           26 2020-05-28 02:22:05          1  zroberts@mit.edu
# 3           26 2020-05-28 02:22:34          1  zroberts@mit.edu
# 4          104 2020-06-30 15:07:24          1  zroberts@mit.edu
# 5           27 2020-07-08 13:24:28          1  zroberts@mit.edu
# 6           26 2020-05-28 02:22:36          1  zroberts@mit.edu
# 7           27 2020-06-03 18:30:11          1    hcelio@mit.edu
# 8           32 2020-07-07 16:59:25          1   mrbraun@mit.edu
# 9           68 2020-07-07 06:00:41          1   mrbraun@mit.edu
# 10         135 2020-07-06 18:10:59          1    wlinde@mit.edu
# 11         115 2020-06-26 15:34:31          1    wlinde@mit.edu
# 12         135 2020-07-06 18:10:59          1    wlinde@mit.edu
# 13         136 2020-06-26 15:30:02          1    wlinde@mit.edu
# 14          81 2020-06-26 15:24:44          1    wlinde@mit.edu
# 15          36 2020-06-23 18:54:08          1    wlinde@mit.edu
# 16         122 2020-07-06 20:38:18          1    wlinde@mit.edu
# 17         101 2020-07-07 21:56:20          1    wlinde@mit.edu
# 18          91 2020-07-03 18:50:39          1    wlinde@mit.edu
# 19          28 2020-06-08 22:35:00          1     mtosi@mit.edu

# %%
all_courses_df = pd.concat([migrated_course_df, all_lt_courses], ignore_index=True)

# %%
ts_cutoff_1w = pd.to_datetime('now') - pd.to_timedelta('7days')
all_courses_df['if_active_last_week'] = np.where(all_courses_df.last_update_at>ts_cutoff_1w, 1, 0)
all_courses_df['if_sandbox_course'] = np.where(all_courses_df.Dept=='Sandboxes', 1, 0)
all_courses_df = all_courses_df[all_courses_df.course_id.notna()].reset_index(drop=True)
all_courses_df.drop_duplicates(subset=['course_id'], keep='last', inplace=True)
#all_courses_df.tail()
# Out:
#     course_id                                               Dept  \
# 20       4113  3 - Department of Materials Science and Engine...
# 21       4226  3 - Department of Materials Science and Engine...
# 22       4164  3 - Department of Materials Science and Engine...
# 23       4183  3 - Department of Materials Science and Engine...
# 24       5073                                          Sandboxes
#
#                             Course_name  num_files  num_assignments  \
# 20   3.042 Materials Project Laboratory         22               14
# 21  3.986 Human Past: Intro Archaeology         63               59
# 22          3.24 Structure of Materials         72               29
# 23     3.42 Electronic Materials Design         49               42
# 24                    Temporary Sandbox         24                4
#
#     num_tot_fa      last_update_at  if_LT_led        LT_email  \
# 20          36 2020-06-23 18:54:08          1  wlinde@mit.edu
# 21         122 2020-07-06 20:38:18          1  wlinde@mit.edu
# 22         101 2020-07-07 21:56:20          1  wlinde@mit.edu
# 23          91 2020-07-03 18:50:39          1  wlinde@mit.edu
# 24          28 2020-06-08 22:35:00          1   mtosi@mit.edu
#
#     if_active_last_week  if_sandbox_course
# 20                    0                  0
# 21                    1                  0
# 22                    1                  0
# 23                    1                  0
# 24                    0                  1

# %%
all_courses_df['last_update_at'] = all_courses_df['last_update_at'].dt.strftime('%Y-%m-%d')
#all_courses_df.tail()

# %%
all_courses_df[all_courses_df.if_sandbox_course==0]
all_courses_df.to_gbq('lt_courses.all_courses2', project_id, if_exists='replace', credentials=credentials)
#all_courses_df.to_csv('all_courses.csv', index=None)
# Out:
# 1it [00:03,  3.94s/it]
